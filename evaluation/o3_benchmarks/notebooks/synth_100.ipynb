# %%
x_0 = 0y_0 = x_0 + 1z_0 = y_0 * 2

# %%
x_1 = 1y_1 = x_1 + 1z_1 = y_1 * 2

# %%
x_2 = 2y_2 = x_2 + 1z_2 = y_2 * 2

# %%
x_3 = 3y_3 = x_3 + 1z_3 = y_3 * 2

# %%
x_4 = 4y_4 = x_4 + 1z_4 = y_4 * 2

# %%
x_5 = 5y_5 = x_5 + 1z_5 = y_5 * 2

# %%
x_6 = 6y_6 = x_6 + 1z_6 = y_6 * 2

# %%
x_7 = 7y_7 = x_7 + 1z_7 = y_7 * 2

# %%
x_8 = 8y_8 = x_8 + 1z_8 = y_8 * 2

# %%
x_9 = 9y_9 = x_9 + 1z_9 = y_9 * 2

# %%
x_10 = 10y_10 = x_10 + 1z_10 = y_10 * 2

# %%
x_11 = 11y_11 = x_11 + 1z_11 = y_11 * 2

# %%
x_12 = 12y_12 = x_12 + 1z_12 = y_12 * 2

# %%
x_13 = 13y_13 = x_13 + 1z_13 = y_13 * 2

# %%
x_14 = 14y_14 = x_14 + 1z_14 = y_14 * 2

# %%
x_15 = 15y_15 = x_15 + 1z_15 = y_15 * 2

# %%
x_16 = 16y_16 = x_16 + 1z_16 = y_16 * 2

# %%
x_17 = 17y_17 = x_17 + 1z_17 = y_17 * 2

# %%
x_18 = 18y_18 = x_18 + 1z_18 = y_18 * 2

# %%
x_19 = 19y_19 = x_19 + 1z_19 = y_19 * 2

# %%
x_20 = 20y_20 = x_20 + 1z_20 = y_20 * 2

# %%
x_21 = 21y_21 = x_21 + 1z_21 = y_21 * 2

# %%
x_22 = 22y_22 = x_22 + 1z_22 = y_22 * 2

# %%
x_23 = 23y_23 = x_23 + 1z_23 = y_23 * 2

# %%
x_24 = 24y_24 = x_24 + 1z_24 = y_24 * 2

# %%
x_25 = 25y_25 = x_25 + 1z_25 = y_25 * 2

# %%
x_26 = 26y_26 = x_26 + 1z_26 = y_26 * 2

# %%
x_27 = 27y_27 = x_27 + 1z_27 = y_27 * 2

# %%
x_28 = 28y_28 = x_28 + 1z_28 = y_28 * 2

# %%
x_29 = 29y_29 = x_29 + 1z_29 = y_29 * 2

# %%
x_30 = 30y_30 = x_30 + 1z_30 = y_30 * 2

# %%
x_31 = 31y_31 = x_31 + 1z_31 = y_31 * 2

# %%
x_32 = 32y_32 = x_32 + 1z_32 = y_32 * 2

# %%
x_33 = 33y_33 = x_33 + 1z_33 = y_33 * 2

# %%
x_34 = 34y_34 = x_34 + 1z_34 = y_34 * 2

# %%
x_35 = 35y_35 = x_35 + 1z_35 = y_35 * 2

# %%
x_36 = 36y_36 = x_36 + 1z_36 = y_36 * 2

# %%
x_37 = 37y_37 = x_37 + 1z_37 = y_37 * 2

# %%
x_38 = 38y_38 = x_38 + 1z_38 = y_38 * 2

# %%
x_39 = 39y_39 = x_39 + 1z_39 = y_39 * 2

# %%
x_40 = 40y_40 = x_40 + 1z_40 = y_40 * 2

# %%
x_41 = 41y_41 = x_41 + 1z_41 = y_41 * 2

# %%
x_42 = 42y_42 = x_42 + 1z_42 = y_42 * 2

# %%
x_43 = 43y_43 = x_43 + 1z_43 = y_43 * 2

# %%
x_44 = 44y_44 = x_44 + 1z_44 = y_44 * 2

# %%
x_45 = 45y_45 = x_45 + 1z_45 = y_45 * 2

# %%
x_46 = 46y_46 = x_46 + 1z_46 = y_46 * 2

# %%
x_47 = 47y_47 = x_47 + 1z_47 = y_47 * 2

# %%
x_48 = 48y_48 = x_48 + 1z_48 = y_48 * 2

# %%
x_49 = 49y_49 = x_49 + 1z_49 = y_49 * 2

# %%
x_50 = 50y_50 = x_50 + 1z_50 = y_50 * 2

# %%
x_51 = 51y_51 = x_51 + 1z_51 = y_51 * 2

# %%
x_52 = 52y_52 = x_52 + 1z_52 = y_52 * 2

# %%
x_53 = 53y_53 = x_53 + 1z_53 = y_53 * 2

# %%
x_54 = 54y_54 = x_54 + 1z_54 = y_54 * 2

# %%
x_55 = 55y_55 = x_55 + 1z_55 = y_55 * 2

# %%
x_56 = 56y_56 = x_56 + 1z_56 = y_56 * 2

# %%
x_57 = 57y_57 = x_57 + 1z_57 = y_57 * 2

# %%
x_58 = 58y_58 = x_58 + 1z_58 = y_58 * 2

# %%
x_59 = 59y_59 = x_59 + 1z_59 = y_59 * 2

# %%
x_60 = 60y_60 = x_60 + 1z_60 = y_60 * 2

# %%
x_61 = 61y_61 = x_61 + 1z_61 = y_61 * 2

# %%
x_62 = 62y_62 = x_62 + 1z_62 = y_62 * 2

# %%
x_63 = 63y_63 = x_63 + 1z_63 = y_63 * 2

# %%
x_64 = 64y_64 = x_64 + 1z_64 = y_64 * 2

# %%
x_65 = 65y_65 = x_65 + 1z_65 = y_65 * 2

# %%
x_66 = 66y_66 = x_66 + 1z_66 = y_66 * 2

# %%
x_67 = 67y_67 = x_67 + 1z_67 = y_67 * 2

# %%
x_68 = 68y_68 = x_68 + 1z_68 = y_68 * 2

# %%
x_69 = 69y_69 = x_69 + 1z_69 = y_69 * 2

# %%
x_70 = 70y_70 = x_70 + 1z_70 = y_70 * 2

# %%
x_71 = 71y_71 = x_71 + 1z_71 = y_71 * 2

# %%
x_72 = 72y_72 = x_72 + 1z_72 = y_72 * 2

# %%
x_73 = 73y_73 = x_73 + 1z_73 = y_73 * 2

# %%
x_74 = 74y_74 = x_74 + 1z_74 = y_74 * 2

# %%
x_75 = 75y_75 = x_75 + 1z_75 = y_75 * 2

# %%
x_76 = 76y_76 = x_76 + 1z_76 = y_76 * 2

# %%
x_77 = 77y_77 = x_77 + 1z_77 = y_77 * 2

# %%
x_78 = 78y_78 = x_78 + 1z_78 = y_78 * 2

# %%
x_79 = 79y_79 = x_79 + 1z_79 = y_79 * 2

# %%
x_80 = 80y_80 = x_80 + 1z_80 = y_80 * 2

# %%
x_81 = 81y_81 = x_81 + 1z_81 = y_81 * 2

# %%
x_82 = 82y_82 = x_82 + 1z_82 = y_82 * 2

# %%
x_83 = 83y_83 = x_83 + 1z_83 = y_83 * 2

# %%
x_84 = 84y_84 = x_84 + 1z_84 = y_84 * 2

# %%
x_85 = 85y_85 = x_85 + 1z_85 = y_85 * 2

# %%
x_86 = 86y_86 = x_86 + 1z_86 = y_86 * 2

# %%
x_87 = 87y_87 = x_87 + 1z_87 = y_87 * 2

# %%
x_88 = 88y_88 = x_88 + 1z_88 = y_88 * 2

# %%
x_89 = 89y_89 = x_89 + 1z_89 = y_89 * 2

# %%
x_90 = 90y_90 = x_90 + 1z_90 = y_90 * 2

# %%
x_91 = 91y_91 = x_91 + 1z_91 = y_91 * 2

# %%
x_92 = 92y_92 = x_92 + 1z_92 = y_92 * 2

# %%
x_93 = 93y_93 = x_93 + 1z_93 = y_93 * 2

# %%
x_94 = 94y_94 = x_94 + 1z_94 = y_94 * 2

# %%
x_95 = 95y_95 = x_95 + 1z_95 = y_95 * 2

# %%
x_96 = 96y_96 = x_96 + 1z_96 = y_96 * 2

# %%
x_97 = 97y_97 = x_97 + 1z_97 = y_97 * 2

# %%
x_98 = 98y_98 = x_98 + 1z_98 = y_98 * 2

# %%
x_99 = 99y_99 = x_99 + 1z_99 = y_99 * 2
