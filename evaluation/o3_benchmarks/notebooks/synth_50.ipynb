# %%
x_0 = 0y_0 = x_0 + 1z_0 = y_0 * 2

# %%
x_1 = 1y_1 = x_1 + 1z_1 = y_1 * 2

# %%
x_2 = 2y_2 = x_2 + 1z_2 = y_2 * 2

# %%
x_3 = 3y_3 = x_3 + 1z_3 = y_3 * 2

# %%
x_4 = 4y_4 = x_4 + 1z_4 = y_4 * 2

# %%
x_5 = 5y_5 = x_5 + 1z_5 = y_5 * 2

# %%
x_6 = 6y_6 = x_6 + 1z_6 = y_6 * 2

# %%
x_7 = 7y_7 = x_7 + 1z_7 = y_7 * 2

# %%
x_8 = 8y_8 = x_8 + 1z_8 = y_8 * 2

# %%
x_9 = 9y_9 = x_9 + 1z_9 = y_9 * 2

# %%
x_10 = 10y_10 = x_10 + 1z_10 = y_10 * 2

# %%
x_11 = 11y_11 = x_11 + 1z_11 = y_11 * 2

# %%
x_12 = 12y_12 = x_12 + 1z_12 = y_12 * 2

# %%
x_13 = 13y_13 = x_13 + 1z_13 = y_13 * 2

# %%
x_14 = 14y_14 = x_14 + 1z_14 = y_14 * 2

# %%
x_15 = 15y_15 = x_15 + 1z_15 = y_15 * 2

# %%
x_16 = 16y_16 = x_16 + 1z_16 = y_16 * 2

# %%
x_17 = 17y_17 = x_17 + 1z_17 = y_17 * 2

# %%
x_18 = 18y_18 = x_18 + 1z_18 = y_18 * 2

# %%
x_19 = 19y_19 = x_19 + 1z_19 = y_19 * 2

# %%
x_20 = 20y_20 = x_20 + 1z_20 = y_20 * 2

# %%
x_21 = 21y_21 = x_21 + 1z_21 = y_21 * 2

# %%
x_22 = 22y_22 = x_22 + 1z_22 = y_22 * 2

# %%
x_23 = 23y_23 = x_23 + 1z_23 = y_23 * 2

# %%
x_24 = 24y_24 = x_24 + 1z_24 = y_24 * 2

# %%
x_25 = 25y_25 = x_25 + 1z_25 = y_25 * 2

# %%
x_26 = 26y_26 = x_26 + 1z_26 = y_26 * 2

# %%
x_27 = 27y_27 = x_27 + 1z_27 = y_27 * 2

# %%
x_28 = 28y_28 = x_28 + 1z_28 = y_28 * 2

# %%
x_29 = 29y_29 = x_29 + 1z_29 = y_29 * 2

# %%
x_30 = 30y_30 = x_30 + 1z_30 = y_30 * 2

# %%
x_31 = 31y_31 = x_31 + 1z_31 = y_31 * 2

# %%
x_32 = 32y_32 = x_32 + 1z_32 = y_32 * 2

# %%
x_33 = 33y_33 = x_33 + 1z_33 = y_33 * 2

# %%
x_34 = 34y_34 = x_34 + 1z_34 = y_34 * 2

# %%
x_35 = 35y_35 = x_35 + 1z_35 = y_35 * 2

# %%
x_36 = 36y_36 = x_36 + 1z_36 = y_36 * 2

# %%
x_37 = 37y_37 = x_37 + 1z_37 = y_37 * 2

# %%
x_38 = 38y_38 = x_38 + 1z_38 = y_38 * 2

# %%
x_39 = 39y_39 = x_39 + 1z_39 = y_39 * 2

# %%
x_40 = 40y_40 = x_40 + 1z_40 = y_40 * 2

# %%
x_41 = 41y_41 = x_41 + 1z_41 = y_41 * 2

# %%
x_42 = 42y_42 = x_42 + 1z_42 = y_42 * 2

# %%
x_43 = 43y_43 = x_43 + 1z_43 = y_43 * 2

# %%
x_44 = 44y_44 = x_44 + 1z_44 = y_44 * 2

# %%
x_45 = 45y_45 = x_45 + 1z_45 = y_45 * 2

# %%
x_46 = 46y_46 = x_46 + 1z_46 = y_46 * 2

# %%
x_47 = 47y_47 = x_47 + 1z_47 = y_47 * 2

# %%
x_48 = 48y_48 = x_48 + 1z_48 = y_48 * 2

# %%
x_49 = 49y_49 = x_49 + 1z_49 = y_49 * 2
